# %% [markdown]
# ---
# format:
#   html:
#     code-fold: show
# ---

# %% [markdown]
# # Calculus
#
# Import the `sympy` module only once at the beginning of your code. It is commonly imported as `sp` to reduce the amount of typing:

# %%
import sympy as sp

# %% [markdown]
# Derivatives (diff), Integrals (integrate), Limits (limit).
