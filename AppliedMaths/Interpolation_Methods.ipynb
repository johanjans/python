# %% [markdown]
# # Interpolation Methods

# %% [markdown]
# - 1D Linear and higher-order interpolation methods.
# - Deriving interpolation functions or basis functions.
#
# - Linear interpolation
#    - Beziér curves
#
# - Piecewise interpolation
#    - Splines (Cubic splines, B-splines)
#    - Hermite interpolation
