# %% [markdown]
# # Numeric Integration

# %% [markdown]
# [fea.ju.se/NumericalIntegration](https://fea.ju.se/NumericalIntegration/)

# %% [markdown]
# ![Riemann sum](graphics/RiemannSum.png){width=30em fig-align="center"}

# %% [markdown]
# ![Trapezoidal sum](graphics/Trapezoidal.gif){width=30em  fig-align="center"}

# %% [markdown]
# ![Gauss sum](graphics/Gauss.gif){width=30em  fig-align="center"}
